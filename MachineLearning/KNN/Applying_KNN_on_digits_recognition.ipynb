# %%
import operator
import os
import numpy as np
#change the folder_path where the file located
folder_path = r"C:\Users\jianyuan\Desktop\Github\DataScience\MachineLearning\KNN"
#try:
#    os.mkdir(folder_path)
#except:
#    pass
os.chdir(folder_path)

# %%
#classify algorithm
def classify0(inx, data_set, labels, k):
    data_set_size = data_set.shape[0]
    #distance calculation
    diff_mat = np.tile(inx,(data_set_size,1)) - data_set
    sq_diff_mat = diff_mat ** 2
    sq_distance = sq_diff_mat.sum(axis=1)
    distance = sq_distance ** 0.5
    
    sorted_dist_indices = distance.argsort()
    classCount = {}
    for i in range(k):
        # voting with lowest k distances
        voteIlabel = labels[sorted_dist_indices[i]]
        classCount[voteIlabel] = classCount.get(voteIlabel,0) + 1
    #sort dictionary
    sortedClassCount = sorted(classCount.items(), key= operator.itemgetter(1), reverse = True)
    return sortedClassCount[0][0]

# %%
#process data: from image to text
def img2vector(filename):
    """creates a 1x1024 NumPy array, then opens the given
    file, loops over the first 32 lines in the file, and stores the integer value of the first 32
    characters on each line in the NumPy array.
    """
    returnVect = np.zeros((1,1024))
    fr = open(filename)
    for i in range(32):
        lineStr = fr.readline()
        for j in range(32):
            returnVect[0, 32*i+j] = int(lineStr[j])
    return returnVect
    
    '''
    file = open(filename)
    returnVect = np.array(list(file.read().replace('\n',''))).astype(int).reshape((1,1024))
    '''

# %%
def handwritingClassTest():
    k = 5
    hwLabels = []
    trainingFileList = os.listdir('trainingDigits')
    m = len(trainingFileList)
    trainingMat = np.zeros((m, 1024))
    for i in range(m):
        fileNameStr = trainingFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        hwLabels.append(classNumStr)
        trainingMat[i,:] = img2vector('trainingDigits/%s'%fileNameStr)
        
    testFileList = os.listdir('testDigits')
    errorCount = 0.0
    mTest = len(testFileList)
    for i in range(mTest):
        fileNameStr = testFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        vectorUnderTest = img2vector('testDigits/%s'%fileNameStr)
        classifierResult = classify0(vectorUnderTest, trainingMat, hwLabels, k)
        print("the classifier came back with: %d, the real answer is: %d"% (classifierResult, classNumStr))
        if (classifierResult != classNumStr): errorCount += 1.0
    print("\nthe total number of errors is: %d" % errorCount)
    print("\nthe total error rate is: %f" % (errorCount/float(mTest)))

# %%
handwritingClassTest()
# Out:
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# ...

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
def handwriting_class_test_sklearn():
    hwLabels = []
    trainingFileList = os.listdir('trainingDigits')
    m = len(trainingFileList)
    trainingMat = np.zeros((m, 1024))
    for i in range(m):
        fileNameStr = trainingFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        hwLabels.append(classNumStr)
        trainingMat[i,:] = img2vector('trainingDigits/%s'%fileNameStr)
        
    testFileList = os.listdir('testDigits')
    errorCount = 0.0
    k = 3
    mTest = len(testFileList)
    for i in range(mTest):
        fileNameStr = testFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        vectorUnderTest = img2vector('testDigits/%s'%fileNameStr)
        nbors = KNeighborsClassifier(n_neighbors=k, algorithm='auto').fit(trainingMat, hwLabels)
        classifierResult = nbors.predict(vectorUnderTest)
        print("the classifier came back with: %d, the real answer is: %d"% (classifierResult, classNumStr))
        if (classifierResult != classNumStr): errorCount += 1.0
    print("\nthe total number of errors is: %d" % errorCount)
    print("\nthe total error rate is: %f" % (errorCount/float(mTest)))

# %%
handwriting_class_test_sklearn()
# Out:
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# the classifier came back with: 0, the real answer is: 0
# ...

# %%
'''The reason that the error rate is different, since the algorithm chosen is different.'''
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import zero_one_loss
#def handwriting_class_test_sklearn(algorithm='auto'):
hwLabels = []
trainingFileList = os.listdir('trainingDigits')
m = len(trainingFileList)
trainingMat = np.zeros((m, 1024))
for i in range(m):
    fileNameStr = trainingFileList[i]
    fileStr = fileNameStr.split('.')[0]
    classNumStr = int(fileStr.split('_')[0])
    hwLabels.append(classNumStr)
    trainingMat[i,:] = img2vector('trainingDigits/%s'%fileNameStr)

testLabels = []
testFileList = os.listdir('testDigits')
errorCount = 0.0
mTest = len(testFileList)
testMat = np.zeros((mTest, 1024))
for i in range(mTest):
    fileNameStr = testFileList[i]
    fileStr = fileNameStr.split('.')[0]
    classNumStr = int(fileStr.split('_')[0])
    testLabels.append(classNumStr)
    testMat[i,:] = img2vector('testDigits/%s'%fileNameStr)

# %%
k = 5
#'brute'
nbors = KNeighborsClassifier(n_neighbors=k, algorithm='brute').fit(trainingMat, hwLabels)
classifierResult = nbors.predict(testMat)
print("\n 'brute' the total error rate is: %f" % (zero_one_loss(testLabels,classifierResult)))

#'kd_tree'
nbors = KNeighborsClassifier(n_neighbors=k, algorithm='kd_tree',leaf_size=1).fit(trainingMat, hwLabels)
classifierResult = nbors.predict(testMat)
print("\n 'kd_tree' the total error rate is: %f" % (zero_one_loss(testLabels,classifierResult)))

#'ball_tree'
nbors = KNeighborsClassifier(n_neighbors=k, algorithm='ball_tree',leaf_size=1).fit(trainingMat, hwLabels)
classifierResult = nbors.predict(testMat)
print("\n 'ball_tree' the total error rate is: %f" % (zero_one_loss(testLabels,classifierResult)))
# Out:
#  'brute' the total error rate is: 0.019027
#
#  'kd_tree' the total error rate is: 0.019027
#
#  'ball_tree' the total error rate is: 0.020085

# %%
'''Warning Regarding the Nearest Neighbors algorithms, 
if it is found that two neighbors, neighbor k+1 and k, 
have identical distances but different labels, 
the results will depend on the ordering of the training data.'''
